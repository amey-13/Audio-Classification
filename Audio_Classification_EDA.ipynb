# %% [markdown]
# # Exploratory Data Analysis

# %%
# !pip3 install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: librosa in /Users/amey/Library/Python/3.9/lib/python/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (1.5.1)
# Requirement already satisfied: joblib>=0.14 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in /Users/amey/Library/Python/3.9/lib/python/site-packages (from lazy-loader>=0.1->librosa) (23.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Library/Python/3.9/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from pooch>=1.1->librosa) (2.28.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /Users/amey/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/amey/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.6.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_name = 'UrbanSound8k/dog_bark.wav'

# %%
import sys
print(sys.executable)
# Out:
# /Users/amey/opt/anaconda3/bin/python

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# Dog Sound

plt.figure(figsize=(14,5))
data, sample_rate = librosa.load(file_name)
librosa.display.waveshow(data, sr=sample_rate)
ipd.Audio(file_name)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Sound

file_name = 'UrbanSound8k/101281-3-0-5-Copy1.wav'

plt.figure(figsize=(14,5))
data, sample_rate = librosa.load(file_name)
librosa.display.waveshow(data, sr=sample_rate)
ipd.Audio(file_name)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(file_name)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[   0,    0],
#        [   0,    0],
#        [   0,    0],
#        ...,
#        [-220,  193],
#        [-211,  203],
#        [-169,  209]], dtype=int16)

# %%
data
# Out:
# array([-4.1909516e-09, -2.4447218e-09, -1.6298145e-09, ...,
#         6.3789585e-03,  2.4849751e-03, -3.8281491e-04], dtype=float32)

# %%
import pandas as pd

metadata = pd.read_csv('UrbanSound8k/metadata/UrbanSound8k.csv')

metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
# Check whether the dataset is balanced

metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
